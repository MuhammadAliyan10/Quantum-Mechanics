# %%
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram
import numpy as np

# %%
qc = QuantumCircuit(1, 1)
qc.rx(np.pi/2, 0)  # Rotate by π/2 around X-axis
qc.measure(0, 0)

# %%
qc.draw(output="mpl")

# %%
simulator = Aer.get_backend('aer_simulator') 

job = simulator.run(qc, shots=1000) 
result = job.result()
counts = result.get_counts()

print("Measurement results:", counts)
plot_histogram(counts)
# Out:
# Measurement results: {'1': 475, '0': 525}

# %% [markdown]
# # Ry

# %%
qc = QuantumCircuit(1, 1)
qc.ry(np.pi/2, 0)  # Rotate by π/2 around Y-axis
qc.measure(0, 0)

# %%
qc.draw(output="mpl")

# %%
simulator = Aer.get_backend('aer_simulator') 

job = simulator.run(qc, shots=1000) 
result = job.result()
counts = result.get_counts()

print("Measurement results:", counts)
plot_histogram(counts)
# Out:
# Measurement results: {'0': 503, '1': 497}

# %% [markdown]
# # Rz

# %%
qc = QuantumCircuit(1, 1)
qc.rz(np.pi/2, 0)  # Rotate by π/2 around Z-axis
qc.measure(0, 0)

# %%
qc.draw(output="mpl")

# %%
simulator = Aer.get_backend('aer_simulator') 

job = simulator.run(qc, shots=1000) 
result = job.result()
counts = result.get_counts()

print("Measurement results:", counts)
plot_histogram(counts)
# Out:
# Measurement results: {'0': 1000}
